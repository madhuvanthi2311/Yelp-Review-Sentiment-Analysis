# %% [markdown]
# # Deep Learning with Natural Language Processing on the Yelp reviews dataset

# %% [markdown]
# ## Reading in some Yelp reviews

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split,StratifiedShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sns
# %matplotlib inline

# %%
# read in the reviews into a DataFrame
yelp = pd.read_csv("yelp_reviews.csv")

# %%
print(yelp.shape)
#Looking into the dataset
yelp.head()

#Value counts of 'stars'

yelp['stars'].value_counts()
# Out:
# (1000000, 4)
# 5    432637
# 4    229402
# 1    140308
# 3    114052
# 2     83601
# Name: stars, dtype: int64

# %%
#Figuring out the number of reviews that businesses receive
number_of_reviews = yelp.business_id.value_counts().value_counts().plot()
sns.mpl.pyplot.xlabel("number of reviews/business")
sns.mpl.pyplot.ylabel("number of businesses")
sns.mpl.pyplot.xlim(0,1000)
sns.mpl.pyplot.ylim(0,1000)
sns.mpl.pyplot.show()

#Most businesses have very few reviews.

# %%
#reviews per user
yelp.user_id.value_counts().value_counts().sort_index().plot()
sns.mpl.pyplot.xlabel("number of reviews/user")
sns.mpl.pyplot.ylabel("number of users")
sns.mpl.pyplot.xlim(0,1000)
sns.mpl.pyplot.ylim(0,1000)
sns.mpl.pyplot.show()

#Both these graphs seem to denote a power law relationship. I plot a log-log plot as the next step

# %%
#reviews per business
yelp.business_id.value_counts().value_counts().sort_index().plot(loglog=True)
sns.mpl.pyplot.xlabel("number of reviews/business")
sns.mpl.pyplot.ylabel("number of businesses")
sns.mpl.pyplot.show()

# %%
#reviews per user
yelp.user_id.value_counts().value_counts().sort_index().plot(loglog=True)
sns.mpl.pyplot.xlabel("number of reviews/user")
sns.mpl.pyplot.ylabel("number of users")
sns.mpl.pyplot.show()

# %%
#To retain meaningful data, we can only look at businesses with > 10 reviews and users with > 10 reviews
#Converting to DataFrame
yelp = pd.DataFrame(yelp)

yelp_smaller = yelp

# %%
#keep only businesses with > 10 reviews, users with > 10 reviews
yelp_smaller = yelp.groupby("business_id").filter(lambda x: x.shape[0]>10)
yelp_smaller = yelp_smaller.groupby("user_id").filter(lambda x: x.shape[0]>10)
#and only the 5-star and <=2 star reviews
yelp_smaller = yelp_smaller[(yelp_smaller.stars==5) | (yelp_smaller.stars<=2)]
#keep only columns we would want to use later

yelp_smaller["target"] = (yelp_smaller.stars >2).astype(int)
print(yelp_smaller.target.value_counts())

yelp_smaller.reset_index(drop=True,inplace=True)

yelp_smaller.head()
# Out:
# 1    95129
# 0    43450
# Name: target, dtype: int64
#               business_id  stars  \
# 0  Aov96CM4FZAXeZvKtsStdA      5
# 1  zgQHtqX0gqMw1nlBZl2VnQ      1
# 2  hjk3ox7w1akbEuOgTJ03Bw      1
# 3  tOhRQqiupLyJdBJVQMGOEQ      5
# 4  I8rveLd-dl81u6c8YqAxmw      1
#
#                                                 text                 user_id  \
# 0  This place is awesome! Definitely authentic!!!...  u0LXt3Uea_GidxRW1xcsfg
# 1  really excited to hear of this restaurant comi...  u0LXt3Uea_GidxRW1xcsfg
# 2  Food is very bland - not authentic at all.\n\n...  u0LXt3Uea_GidxRW1xcsfg
# 3  OMG - Definitely worth going if you are in Mon...  u0LXt3Uea_GidxRW1xcsfg
# 4  If you have not yet tried Wasabi - don't bothe...  u0LXt3Uea_GidxRW1xcsfg
#
#    target
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0

# %% [markdown]
# - **corpus:** collection of documents
# - **corpora:** plural form of corpus

# %% [markdown]
# Using StratifiedShuffleSplit to preserve imbalance in the target data

# %%
# split the new DataFrame into training and testing sets, keeping relative frequencies of targets unchanged
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.3,random_state=1)
train_indices,test_indices=list(splitter.split(yelp_smaller.text,yelp_smaller.target))[0]
X_train,y_train = yelp_smaller.text.iloc[train_indices],yelp_smaller.target.iloc[train_indices]
X_test,y_test = yelp_smaller.text.iloc[test_indices],yelp_smaller.target.iloc[test_indices]

# %%
y_train.value_counts()/y_train.shape[0]
# Out:
# 1    0.686459
# 0    0.313541
# Name: target, dtype: float64

# %%
y_test.value_counts()/y_test.shape[0]
# Out:
# 1    0.686463
# 0    0.313537
# Name: target, dtype: float64

# %% [markdown]
# ## Tokenization

# %%
# use CountVectorizer to create document-term matrices from X_train and X_test
vect = CountVectorizer(lowercase=False)
train_dtm = vect.fit_transform(X_train)
test_dtm = vect.transform(X_test)

# %%
# rows are documents, columns are features
train_dtm.shape
# Out:
# (97005, 108635)

# %%
# last 50 features
print(vect.get_feature_names()[50:500])
# Out:
# [u'04pm', u'05', u'050', u'0500am', u'0509', u'054', u'0545', u'0548', u'05AM', u'05a', u'05am', u'05p', u'05pm', u'06', u'0600', u'0630', u'06pm', u'07', u'0716', u'0730', u'074', u'0757', u'079', u'07am', u'08', u'0810', u'0830', u'0835', u'08am', u'09', u'090', u'0900', u'0905', u'0912', u'0930', u'094', u'097', u'09pm', u'0P', u'0_0', u'0_O', u'0admission', u'0stars', u'0ther', u'0ut', u'0x10', u'0z', u'10', u'100', u'1000', u'10000', u'100000', u'1000000', u'100000000000', u'100000000000000000000000000000000000000000000', u'10000000X', u'1000000x', u'100000x', u'10000degrees', u'1000X', u'1000cc', u'1000f', u'1000g', u'1000s', u'1000x', u'1001', u'100111fa_fact_seabrook', u'1003rd', u'1008', u'100F', u'100Fs', u'100K', u'100X', u'100g', u'100ish', u'100k', u'100lb', u'100lbs', u'100m', u'100mbps', u'100mg', u'100mm', u'100oz', u'100percent', u'100pp', u'100s', u'100th', u'100x', u'101', u'1012', u'10127', u'1015', u'101st', u'102', u'1023', u'1024GB', u'1025am', u'1026', u'1029', u'103', u'1030', u'1030am', u'1030ish', u'1030pm', u'10345', u'10394585_1620289958195386_7688075413347857986_n', u'103rd', u'104', u'1040', u'10420', u'1045', u'1045a', u'1045pm', u'105', u'1050', u'1055', u'1057', u'1058', u'105each', u'105o', u'106', u'106k', u'106th', u'107', u'107lbs', u'107th', u'108', u'1082', u'108th', u'109', u'1092nd', u'1097967', u'109th', u'10AM', u'10AWG', u'10Am', u'10K', u'10Mbps', u'10PM', u'10X', u'10a', u'10am', u'10az', u'10bucks', u'10days', u'10different', u'10h', u'10in', u'10inch', u'10ish', u'10k', u'10lb', u'10lbs', u'10m', u'10mbps', u'10megs', u'10miles', u'10min', u'10mins', u'10mint', u'10minutes', u'10months', u'10ounce', u'10oz', u'10p', u'10pc', u'10pcs', u'10pm', u'10ppl', u'10s', u'10small', u'10th', u'10ths', u'10w30', u'10x', u'10x15', u'10xs', u'10yards', u'10years', u'10yr', u'10yrs', u'11', u'110', u'1100', u'1101794', u'1102', u'110F', u'110am', u'111', u'1110a', u'111111', u'1111111', u'1113', u'1115', u'111am', u'112', u'113', u'1130', u'1130am', u'1130pm', u'114', u'1140am', u'1142', u'1145', u'1146', u'114pound', u'115', u'1150', u'115020347051893738999', u'1155PM', u'1158', u'115F', u'116', u'116th', u'117', u'117th', u'118', u'119', u'1195', u'11AM', u'11PM', u'11a', u'11am', u'11in', u'11ish', u'11k', u'11min', u'11months', u'11oz', u'11p', u'11pcs', u'11pm', u'11s', u'11th', u'11yrs', u'12', u'120', u'1200', u'12000', u'1200sq', u'12011', u'120K', u'120MPH', u'120k', u'120lb', u'120min', u'120pm', u'121', u'1213', u'1215', u'122', u'1226', u'123', u'1230', u'1230am', u'1230pm', u'1234', u'1236', u'1237', u'123k', u'124', u'1242pm', u'1247', u'125', u'1250', u'1250am', u'125ml', u'126', u'1260626', u'127', u'128', u'128i', u'128oz', u'129', u'129286', u'12AM', u'12K', u'12PM', u'12TOMATO', u'12W', u'12a', u'12am', u'12ft', u'12h', u'12in', u'12ish', u'12k', u'12months', u'12noon', u'12oz', u'12p', u'12pcs', u'12pm', u'12s', u'12th', u'12x', u'12yr', u'13', u'130', u'1300', u'13000', u'1300mg', u'130am', u'130k', u'130pm', u'131', u'131f', u'132', u'133', u'134', u'134th', u'135', u'137', u'1377384893', u'137f', u'138', u'1380', u'138oz', u'139', u'1395', u'1397', u'139776', u'13BvQFe', u'13_17', u'13g', u'13hr', u'13ish', u'13miles', u'13oz', u'13th', u'13yr', u'14', u'140', u'1400', u'14000', u'1400s', u'142', u'143', u'1430', u'144', u'145', u'1450', u'1455', u'146', u'147', u'148', u'149', u'1495', u'14998', u'14Angostura', u'14g', u'14in', u'14inch', u'14k', u'14mile', u'14oz', u'14pcs', u'14pm', u'14th', u'14years', u'14yo', u'14yr', u'15', u'150', u'1500', u'15000', u'1500hrs', u'1500mg', u'150K', u'150mbps', u'150plus', u'150pp', u'150th', u'151', u'1511', u'152', u'1520', u'153', u'1540', u'155', u'1554', u'1557', u'156', u'157', u'158', u'159', u'1595', u'15AM', u'15K', u'15MB', u'15PM', u'15Roasted', u'15W', u'15X', u'15a', u'15am', u'15and', u'15c', u'15cents', u'15e976c7d5c4330fbdd1f53e56f1488a_full_size', u'15ish', u'15k', u'15m', u'15min', u'15mins', u'15minute', u'15min ...

# %%
# show vectorizer options
vect
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %% [markdown]
# We do not change the text to lowercase because uppercase reviews might actually convey meaning in this case

# %%
# allow tokens of one character
vect = CountVectorizer(token_pattern=r'(?u)\b\w+\b', lowercase= False)
train_dtm = vect.fit_transform(X_train)
test_dtm = vect.fit_transform(X_test)
train_dtm.shape
# Out:
# (97005, 108707)

# %%
# last 50 features
print(vect.get_feature_names()[-50:])
# Out:
# ['都是經典的美式家常風味 點餐完畢後就找個位置等候叫號取餐', '配角也是一時之選', '配角也是一時之選 玉米麵包鬆軟香甜', '量はアメリカサイズなので頼みすぎにはご注意を', '鍋貼', '鍋貼 the', '锅贴', '锅贴 fried', '開懷大吃的用餐去處', '開懷大吃的用餐去處 就像是這間在當地小有名氣', '除了造訪在主街大道上那些華麗豐盛的自助餐與名廚餐廳', '除了造訪在主街大道上那些華麗豐盛的自助餐與名廚餐廳 也別忘了這間風格鮮明', '雖然外觀其貌不揚', '雖然外觀其貌不揚 但濃郁的香味從端上桌起就久久不散', '雖然組合套餐的肉品看起來都相當誘人', '雖然組合套餐的肉品看起來都相當誘人 但是首次造訪還是選擇了自己喜歡的肉品為主', '雖然美產和牛在這裡販售的價格確實不低', '雖然美產和牛在這裡販售的價格確實不低 但其它各種肉品單點一份的消費水準算是與在南加州普遍的價格相差不遠', '雖然醬汁有點過多但吃來仍是有趣的開胃點心', '雖然醬汁有點過多但吃來仍是有趣的開胃點心 雖然組合套餐的肉品看起來都相當誘人', '顧客可以依照自己的預算與喜好來選擇', '顧客可以依照自己的預算與喜好來選擇 其實也都可以吃得很飽', '顧客可以自行選擇喜歡的食材和調味', '顧客可以自行選擇喜歡的食材和調味 由廚師現場幫忙料理的服務', '餐廳外觀看起來也就像是一間農舍', '餐廳外觀看起來也就像是一間農舍 其實裡頭只是點餐區', '餐後再來一份炸香蕉天婦羅冰淇淋', '餐後再來一份炸香蕉天婦羅冰淇淋 透過香甜的滋味來中和一下口中過度滿溢的肉香風味', '餐點的精緻程度都比起以往吃過許多價位相近的自助餐高出許多', '餐點的精緻程度都比起以往吃過許多價位相近的自助餐高出許多 也有不少帶有亮點的餐點', '首先吸引目光的當然就是自助餐中人氣菜色的帝王蟹腳', '首先吸引目光的當然就是自助餐中人氣菜色的帝王蟹腳 這裡所提供的蟹腳是經過挑選的', '香檳選用來自法國進口的', '香檳選用來自法國進口的 perrier', '香腸', '香腸 烤雞等等', '香辣回甘的烤肉醬', '香辣回甘的烤肉醬 唯一比較平凡的是起司通心粉', '鬆軟的香蕉蛋糕', '鬆軟的香蕉蛋糕 透過各種看似樸素的美式早餐元素', '魚料理からデザートに至るまでどれもお勧めです', '魚料理からデザートに至るまでどれもお勧めです 特にlouis', '鮮蝦', '鮮蝦 淡菜', '點餐完畢後就找個位置等候叫號取餐', '點餐完畢後就找個位置等候叫號取餐 受到美食節目大力推薦的烤肉風味', '龍蝦', '龍蝦 牛排', '龍蝦尾有著一般只在單點的海鮮餐廳或是高級牛排館中才吃得到的水準之作', '龍蝦尾有著一般只在單點的海鮮餐廳或是高級牛排館中才吃得到的水準之作 並不會因為是採用自助餐的方式提供而對品質有所折扣']

# %% [markdown]
# **Predicting 5(positive) vs. 1/2(negative) star rating:**

# %%
# use default options for CountVectorizer
vect = CountVectorizer(lowercase = False)

# create document-term matrices
train_dtm = vect.fit_transform(X_train)
test_dtm = vect.transform(X_test)

# use Logistic Regression to predict the star rating
lr = LogisticRegression()
lr.fit(train_dtm, y_train)
y_pred_class = lr.predict(test_dtm)

# calculate accuracy
print(metrics.accuracy_score(y_test, y_pred_class))
# Out:
# 0.954009717612

# %%
# calculate null accuracy
y_test.mean()
# Out:
# 0.6864626930292972

# %% [markdown]
# Just using raw counts of different words gives us very good performance!
#
# Let's examine the most positive and most negative words (their coefficients will tell us whether they are most indicative of a positive or negative review).

# %%
feature_coeffs = pd.DataFrame(list(zip(vect.get_feature_names(),lr.coef_[0])),columns=["word","coeff"])
feature_coeffs = feature_coeffs.sort_values(by="coeff",ascending=False).reset_index(drop=True)

# %% [markdown]
# Words most indicative of positive review:

# %%
feature_coeffs.head()
# Out:
#          word     coeff
# 0  perfection  2.618981
# 1   Excellent  2.551140
# 2   Delicious  2.496276
# 3     Amazing  2.446885
# 4  pleasantly  2.413750

# %% [markdown]
# Words most indicative of negative review:

# %%
feature_coeffs.tail()
# Out:
#              word     coeff
# 108630  poisoning -2.844305
# 108631     lacked -2.945091
# 108632   mediocre -3.016717
# 108633        Meh -3.055873
# 108634      worst -3.120588

# %%
feature_coeffs["abs_coeff"] = feature_coeffs.coeff.abs()

# %% [markdown]
# Most predictive words, regardless of polarity:

# %%
feature_coeffs.sort_values(by="abs_coeff",inplace=True,ascending=False)
feature_coeffs.head(100)
# Out:
#                  word     coeff  abs_coeff
# 108634          worst -3.120588   3.120588
# 108633            Meh -3.055873   3.055873
# 108632       mediocre -3.016717   3.016717
# 108631         lacked -2.945091   2.945091
# 108630      poisoning -2.844305   2.844305
# 108629          bland -2.686634   2.686634
# 108628  disappointing -2.685825   2.685825
# 0          perfection  2.618981   2.618981
# 108627          worse -2.590125   2.590125
# 108626          Worst -2.586962   2.586962
# 1           Excellent  2.551140   2.551140
# 2           Delicious  2.496276   2.496276
# 108625           rude -2.476798   2.476798
# 3             Amazing  2.446885   2.446885
# 4          pleasantly  2.413750   2.413750
# 108624       horrible -2.396259   2.396259
# 5                 gem  2.362308   2.362308
# 108623     overpriced -2.361392   2.361392
# 108622         subpar -2.359922   2.359922
# 6           fantastic  2.278327   2.278327
# 7           excellent  2.269664   2.269664
# 108621         ruined -2.204487   2.204487
# 108620          WORST -2.197547   2.197547
# 108619    forgettable -2.181836   2.181836
# 108618      tasteless -2.178056   2.178056
# 8          incredible  2.171573   2.171573
# 108617        lacking -2.165899   2.165899
# 108616          sucks -2.153171   2.153171
# 9             Awesome  2.142908   2.142908
# 10               Best  2.128623   2.128623
# ...               ...       ...        ...
# 108590          stale -1.796912   1.796912
# 26            awesome  1.785449   1.785449
# 108589           poor -1.767970   1.767970
# 27              Thank  1.766550   1.766550
# 28            pleased  1.748241   1.748241
# 108588        watered -1.732723   1.732723
# 108587   Disappointed -1.719328   1.719328
# 29          Wonderful  1.705056   1.705056
# 108586          clips -1.705028   1.705028
# 108585          waste -1.703221   1.703221
# 108584          Awful -1.694039   1.694039
# 108583          Sorry -1.689429   1.689429
# 108582       TERRIBLE -1.689392   1.689392
# 30          wonderful  1.688561   1.688561
# 108581       HORRIBLE -1.683320   1.683320
# 31           fabulous  1.682620   1.682620
# 108580   inconsistent -1.677478   1.677478
# 108579   underwhelmed -1.669916   1.669916
# 32              Hands  1.662871   1.662871
# 108578         poorly -1.647494   1.647494
# 108577       Terrible -1.646334   1.646334
# 108576             OK -1.642452   1.642452
# 33             Highly  1.642283   1.642283
# 34            worried  1.632560   1.632560
# 108575          burnt -1.631209   1.631209
# 108574         filthy -1.626723   1.626723
# 35           cleaners  1.614703   1.614703
# 108573     depressing -1.614495   1.614495
# 36             licked  1.613475   1.613475
# 108572           luck -1.611748   1.611748
#
# [100 rows x 3 columns]

# %% [markdown]
# Useless words (dont tell you anything about the polarity of the review):

# %%
feature_coeffs.tail(20)
# Out:
#                              word         coeff     abs_coeff
# 63547                    seascape  9.487805e-10  9.487805e-10
# 5210                       aonori  9.487805e-10  9.487805e-10
# 6012                         asee -9.365727e-10  9.365727e-10
# 8221                    beautfiul  8.861788e-10  8.861788e-10
# 67818                   sprayback  8.861788e-10  8.861788e-10
# 11490                   brushback  8.861788e-10  8.861788e-10
# 67238                  spaceballs -7.469574e-10  7.469574e-10
# 73839                        tris  5.331116e-10  5.331116e-10
# 3323                          aec -4.901027e-10  4.901027e-10
# 3924                    albemarle  4.670562e-10  4.670562e-10
# 63495  seafoodconnectioncharlotte  4.670562e-10  4.670562e-10
# 36717                   impressor -4.596051e-10  4.596051e-10
# 76179                       vally  4.571942e-10  4.571942e-10
# 56708                  projectile  4.571942e-10  4.571942e-10
# 490                           176  4.571942e-10  4.571942e-10
# 78534                       whist  3.173862e-10  3.173862e-10
# 29100                       foxes  2.611585e-10  2.611585e-10
# 13897                      centry  2.022272e-10  2.022272e-10
# 25722                         etf  2.022272e-10  2.022272e-10
# 55365                   pompously -3.329725e-11  3.329725e-11

# %%
feature_coeffs.head()
# Out:
#              word     coeff
# 1014481  mediocre -2.269419
# 1390272      rude -2.308172
# 227413      bland -2.327143
# 796957   horrible -2.341918
# 1888016     worst -2.704091

# %% [markdown]
# ## Pipelines To Make CV/Transformations Easier With Imbalanced Data

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
yelp_pipeline = Pipeline([("countVect",CountVectorizer(max_features=1000)),
                     ("logreg",LogisticRegression())])

# %%
strat_cv = StratifiedKFold(n_splits=2)

# %%
np.mean(cross_val_score(yelp_pipeline,
                yelp_smaller.text,
                yelp_smaller.target,
                scoring="accuracy",
                cv=strat_cv,
                n_jobs=-1,
                verbose=1))
# Out:
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   48.6s finished
# 0.93682303774006592

# %%
yelp_pipeline.fit(yelp_smaller.text,yelp_smaller.target)
# Out:
# Pipeline(memory=None,
#      steps=[('countVect', CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=1000, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#      ...ty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
# lets create a function that accepts a vectorizer and returns a table with the coefficients and accuracy of cv-ed model
def tokenize_test(vect):
    pipe = Pipeline([("vect",vect),("lr",LogisticRegression())])
    pipe.fit(yelp_smaller.text,yelp_smaller.target)
    num_features = len(pipe.steps[0][1].get_feature_names())
    print('Num Features: ', num_features)

    zipped_coeffs = list(zip(pipe.steps[0][1].get_feature_names(),
                             pipe.steps[1][1].coef_[0]))
    feature_coeffs = pd.DataFrame(zipped_coeffs,columns=["word","coeff"]).sort_values(by="coeff",ascending=False)
    feature_coeffs.reset_index(drop=True,inplace=True)

    strat_cv = StratifiedKFold(n_splits=2)
    acc = np.mean(cross_val_score(pipe,
                yelp_smaller.text,
                yelp_smaller.target,
                scoring="accuracy",
                cv=strat_cv,
                n_jobs=-1,
                verbose=1))
    print("Accuracy:", acc)
    return (feature_coeffs, acc)

# %%
# include 1-grams and 2-grams
vect = CountVectorizer(ngram_range=(1, 2), max_features=1000)
feature_coeffs,acc = tokenize_test(vect)
# Out:
# ('Num Features: ', 1000)
# ('Accuracy:', 0.93145425871219623)
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:  1.9min finished

# %%
feature_coeffs.head(10)
# Out:
#             word     coeff
# 0        perfect  1.918178
# 1      excellent  1.791543
# 2      delicious  1.763510
# 3      perfectly  1.748481
# 4      fantastic  1.626933
# 5      wonderful  1.608156
# 6        amazing  1.601015
# 7        awesome  1.597574
# 8  definitely be  1.533123
# 9        so good  1.496903

# %%
feature_coeffs.sort_values("coeff").head(10)
# Out:
#          word     coeff
# 999     worst -2.973066
# 998     bland -2.527896
# 997  horrible -2.284500
# 996      rude -2.157749
# 995  terrible -2.077058
# 994   average -1.244444
# 993      slow -1.184293
# 992        ok -1.179365
# 991    won be -1.151279
# 990  good but -1.109262

# %% [markdown]
# ## Stopword Removal

# %%
# show vectorizer options
vect
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=1000, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# remove English stop words
vect = CountVectorizer(stop_words='english',max_features=1000, min_df=0.005, max_df = 0.7)
feature_coeffs,acc = tokenize_test(vect)
# Out:
# ('Num Features: ', 1000)
# ('Accuracy:', 0.92812042295939945)
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   40.5s finished

# %%
feature_coeffs.head(10)
# Out:
#          word     coeff
# 0  perfection  2.970434
# 1  incredible  2.250750
# 2     perfect  1.834952
# 3  refreshing  1.816420
# 4   delicious  1.797711
# 5     amazing  1.768291
# 6         gem  1.745482
# 7      heaven  1.744718
# 8   excellent  1.709713
# 9     awesome  1.674504

# %%
feature_coeffs.tail(10).sort_values("coeff")
# Out:
#                word     coeff
# 999        mediocre -3.038727
# 998   disappointing -3.011271
# 997           worst -2.865411
# 996  disappointment -2.643775
# 995           bland -2.631474
# 994        horrible -2.390245
# 993      overpriced -2.386246
# 992        terrible -2.226602
# 991            rude -2.014735
# 990           worse -1.949214

# %%
# set of stop words
print(vect.get_stop_words())
# Out:
# frozenset(['all', 'six', 'less', 'being', 'indeed', 'over', 'move', 'anyway', 'fifty', 'four', 'not', 'own', 'through', 'yourselves', 'go', 'where', 'mill', 'only', 'find', 'before', 'one', 'whose', 'system', 'how', 'somewhere', 'with', 'thick', 'show', 'had', 'enough', 'should', 'to', 'must', 'whom', 'seeming', 'under', 'ours', 'has', 'might', 'thereafter', 'latterly', 'do', 'them', 'his', 'around', 'than', 'get', 'very', 'de', 'none', 'cannot', 'every', 'whether', 'they', 'front', 'during', 'thus', 'now', 'him', 'nor', 'name', 'several', 'hereafter', 'always', 'who', 'cry', 'whither', 'this', 'someone', 'either', 'each', 'become', 'thereupon', 'sometime', 'side', 'two', 'therein', 'twelve', 'because', 'often', 'ten', 'our', 'eg', 'some', 'back', 'up', 'namely', 'towards', 'are', 'further', 'beyond', 'ourselves', 'yet', 'out', 'even', 'will', 'what', 'still', 'for', 'bottom', 'mine', 'since', 'please', 'forty', 'per', 'its', 'everything', 'behind', 'un', 'above', 'between', 'it', 'neither', 'seemed', 'ever', 'across', 'she', 'somehow', 'be', 'we', 'full', 'never', 'sixty', 'however', 'here', 'otherwise', 'were', 'whereupon', 'nowhere', 'although', 'found', 'alone', 're', 'along', 'fifteen', 'by', 'both', 'about', 'last', 'would', 'anything', 'via', 'many', 'could', 'thence', 'put', 'against', 'keep', 'etc', 'amount', 'became', 'ltd', 'hence', 'onto', 'or', 'con', 'among', 'already', 'co', 'afterwards', 'formerly', 'within', 'seems', 'into', 'others', 'while', 'whatever', 'except', 'down', 'hers', 'everyone', 'done', 'least', 'another', 'whoever', 'moreover', 'couldnt', 'throughout', 'anyhow', 'yourself', 'three', 'from', 'her', 'few', 'together', 'top', 'there', 'due', 'been', 'next', 'anyone', 'eleven', 'much', 'call', 'therefore', 'interest', 'then', 'thru', 'themselves', 'hundred', 'was', 'sincere', 'empty', 'more', 'himself', 'elsewhere', 'mostly', 'on', 'fire', 'am', 'becoming', 'hereby', 'amongst', 'else', 'part', 'everywhere', 'too', 'herself', 'former', 'those', 'he', 'me', 'myself', 'made', 'twenty', 'these', 'bill', 'cant', 'us', 'until', 'besides', 'nevertheless', 'below', 'anywhere', 'nine', 'can', 'of', 'toward', 'my', 'something', 'and', 'whereafter', 'whenever', 'give', 'almost', 'wherever', 'is', 'describe', 'beforehand', 'herein', 'an', 'as', 'itself', 'at', 'have', 'in', 'seem', 'whence', 'ie', 'any', 'fill', 'again', 'hasnt', 'inc', 'thereby', 'thin', 'no', 'perhaps', 'latter', 'meanwhile', 'when', 'detail', 'same', 'wherein', 'beside', 'also', 'that', 'other', 'take', 'which', 'becomes', 'you', 'if', 'nobody', 'see', 'though', 'may', 'after', 'upon', 'most', 'hereupon', 'eight', 'but', 'serious', 'nothing', 'such', 'your', 'why', 'a', 'off', 'whereby', 'third', 'i', 'whole', 'noone', 'sometimes', 'well', 'amoungst', 'yours', 'their', 'rather', 'without', 'so', 'five', 'the', 'first', 'whereas', 'once'])

# %% [markdown]
# ## Other CountVectorizer Options

# %% [markdown]
# - **max_features:** int or None, default=None
# - If not None, build a vocabulary that only consider the top max_features ordered by term frequency across the corpus.
#
# - **min_df:** float in range [0.0, 1.0] or int, default=1
# - When building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold. This value is also called cut-off in the literature. If float, the parameter represents a proportion of documents, integer absolute counts.

# %%
# remove English stop words and only keep words appearing in 0.5% of documents
vect = CountVectorizer(stop_words='english', min_df = 0.005)
features,acc = tokenize_test(vect)
# Out:
# Num Features:  903
# Accuracy: 0.9264967972602557
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   18.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   18.8s finished

# %%
features.head()
# Out:
#          word     coeff
# 0  perfection  2.978810
# 1  incredible  2.187778
# 2     perfect  1.840201
# 3   delicious  1.794762
# 4     amazing  1.745237

# %%
features.sort_values("coeff").head()
# Out:
#               word     coeff
# 902       mediocre -3.033634
# 901  disappointing -2.984644
# 900          worst -2.876168
# 899          bland -2.606862
# 898     overpriced -2.394464

# %%
# include 1-grams and 2-grams, and only include terms that appear at least 20 times
vect = CountVectorizer(ngram_range=(1, 2), min_df=20)
features,acc = tokenize_test(vect)
# Out:
# Num Features:  99926
# Accuracy: 0.9643019473337249
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:  1.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:  1.1min finished

# %%
features.head()
# Out:
#                word     coeff
# 0         excellent  2.524480
# 1   be disappointed  2.327470
# 2  not disappointed  2.312735
# 3         delicious  2.275090
# 4           awesome  2.140078

# %%
features.sort_values("coeff").head()
# Out:
#              word     coeff
# 99925       worst -2.961418
# 99924   not worth -2.837520
# 99923   two stars -2.612489
# 99922     at best -2.557048
# 99921  overpriced -2.550226

# %% [markdown]
# ## Using TF-IDF to Summarize a Yelp Review

# %%
# create a document-term matrix using TF-IDF
vect = TfidfVectorizer(stop_words='english')
dtm = vect.fit_transform(yelp_smaller.text)
features = vect.get_feature_names()
dtm.shape
# Out:
# (138579, 95834)

# %%
from textblob import TextBlob
def summarize():
    
    # choose a random review that is at least 500 characters
    review_length = 0
    while review_length < 500:
        review_id = np.random.randint(0, len(yelp_smaller))
        review_text = yelp_smaller.text.iloc[review_id]
        review_length = len(review_text)
    
    # create a dictionary of words and their TF-IDF scores
    word_scores = {}
    for word in TextBlob(review_text).words:
        word = word.lower()
        if word in features:
            word_scores[word] = dtm[review_id, features.index(word)]
    
    # print words with the top 5 TF-IDF scores
    print('TOP SCORING WORDS:')
    top_scores = sorted(word_scores.items(), key=lambda x: x[1], reverse=True)[:5]
    for word, score in top_scores:
        print(word)
    
    # print 5 random words
    print('\n' + 'RANDOM WORDS:')
    random_words = np.random.choice(list(word_scores.keys()), size=5, replace=False)
    for word in random_words:
        print(word)
    
    # print the review
    print('\n' + review_text)

# %%
summarize()
# Out:
# TOP SCORING WORDS:
# napkin
# set
# silverware
# fruits
# steamed
#
# RANDOM WORDS:
# food
# 10
# wo
# unappealing
# believe
#
# If you have a total rewards card you get $1 off the $24 lunch buffet.  To be honest I just wasn't very impressed with the range of food that was offered here.  A lot of foods were repeated in different stations such as rice and fatty pasta dishes.  The salad station was also very weak, and honestly I had wanted to fill up on good veggies or fruits.  There were not a lot of vegetable options and the fruits that were there (ex cut up honeydew) looked old and unappealing.  The best items I had there were the steamed clams, steamed mussels, a berry crepe, and the macaroons.  There were also mini eclairs and those I generally love but it was pretty dry and the frosting layer was thin and hard.  I would rather pay $25 somewhere else and get one nice plate of fish or salad.  Also, I think this price included a soft drink.  The people up front don't ask you if you even want a drink I think they just charge you for it and assume you will get a soft drink.  For me this wasn't a good deal because I only wanted water.  I definitely won't be back.  On a side note another reason I wouldn't venture back is because I asked for another set of silver ware that never came from my server, so I had to steal a new set off another table.  When I opened the new set all the silverware inside the napkin were horribly and visibly dirty!  I can't believe some server actually took the time to take those filthy pieces of silverware, put them in a napkin and ROLL THEM UP in it.  Just not worth the price.  Sorry!  The workers were friendly but the food options, quality of food, and cleanliness are only worth about $10- $15.

# %% [markdown]
# ## PPMI

# %%
cv = CountVectorizer(max_features=50000)
data = cv.fit_transform(yelp_smaller.text)

# %%
data.shape
# Out:
# (138579, 50000)

# %%
freq_term = data.sum(axis=0)
freq_doc = data.sum(axis=1)
p_x=data/freq_term
p_y = freq_doc/freq_doc.sum()
pmi = np.log((p_x/p_y)+.001)
ppmi = pmi.clip(0)
ppmi[np.isnan(ppmi)] = 0

# %%
ppmi = sp.sparse.csr_matrix(ppmi)

# %%
X_train,X_test,y_train,y_test = ppmi[train_indices], ppmi[test_indices], yelp_smaller.target.iloc[train_indices], yelp_smaller.target.iloc[test_indices]
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred_class = lr.predict(X_test)
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred_class))

# %% [markdown]
# ## Stemming and Lemmatization

# %%
# initialize stemmer
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer('english')


review_id = np.random.randint(0, len(yelp_smaller))
review = TextBlob(yelp_smaller.text.iloc[review_id])

# stem each word
print([stemmer.stem(word) for word in review.words])
# Out:
# [u'first', u'time', u'here', u'caus', u'peopl', u'told', u'they', u'have', u'good', u'pizza', u'gave', u'it', u'a', u'shot.they', u'do', u"n't", u'have', u'good', u'pizza', u'they', u'have', u'great', u'pizza', u'this', u'is', u'east', u'coast', u'jersey', u'new', u'york', u'boardwalk', u'style', u'thin', u'crust', u'fold', u'it', u'in', u'half', u'and', u'use', u'your', u'hand', u'pizza.if', u'you', u'want', u'to', u'use', u'a', u'knife', u'and', u'fork', u'to', u'eat', u'your', u'pizza', u'go', u'back', u'to', u'chitown', u'where', u'you', u'came', u'from', u'i', u'will', u'be', u'come', u'back']

# %% [markdown]
# **Lemmatization**
#
# - **What:** Derive the canonical form ('lemma') of a word
# - **Why:** Can be better than stemming
# - **Notes:** Uses a dictionary-based approach (slower than stemming)

# %%
# assume every word is a noun
print([word.lemmatize() for word in review.words])
# Out:
# ['first', 'time', 'here', 'cause', 'people', 'told', 'they', 'have', 'good', 'pizza', 'gave', 'it', 'a', 'shot.they', 'do', "n't", 'have', 'good', 'pizza', 'THEY', 'HAVE', 'GREAT', 'PIZZA', 'this', 'is', 'east', 'coast', 'jersey', 'new', 'York', 'boardwalk', 'style', 'thin', 'crust', 'fold', 'it', 'in', 'half', 'and', 'use', 'your', u'hand', 'pizza.if', 'you', 'want', 'to', 'use', 'a', 'knife', 'and', 'fork', 'to', 'eat', 'your', 'pizza', 'go', 'back', 'to', 'chitown', 'where', 'you', 'came', 'from', 'I', 'will', 'be', 'coming', 'back']

# %%
# assume every word is a verb
print([word.lemmatize(pos='v') for word in review.words])
# Out:
# ['This', 'place', 'be', 'awesome', 'Definitely', 'authentic', 'My', 'two', 'favourite', 'dish', 'be', 'the', 'rice', 'flour', 'roll', 'and', 'the', 'chicken', 'pho', 'The', 'rice', 'flour', 'roll', 'be', 'always', 'fresh', 'whenever', 'I', "'m", 'there', 'And', 'the', 'chicken', 'pho', 'be', 'always', 'flavourful', 'mmmm', 'just', 'think', 'of', 'it', 'make', 'me', 'want', 'some', 'My', 'boyfriend', 'be', 'Vietnamese', 'and', 'he', 'agree', 'that', 'this', 'place', 'be', 'authentic', 'and', 'one', 'of', 'the', 'best', 'Vietnamese', 'restaurants', 'he', 'have', 'ever', 'eat', 'at', 'Prices', 'be', 'very', 'reasonable', 'too']

# %%
# define a function that accepts text and returns a list of lemmas
def split_into_lemmas(text):
    text = text.lower()
    words = TextBlob(text).words
    return [word.lemmatize() for word in words]

# %%
# use split_into_lemmas as the feature extraction function
vect = CountVectorizer(analyzer=split_into_lemmas)
features,acc = tokenize_test(vect)
# Out:
# Num Features:  127004
# Accuracy: 0.9517170710745169
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:  9.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:  9.8min finished

# %%
features.head()
# Out:
#          word     coeff
# 0  pleasantly  2.963142
# 1  perfection  2.852115
# 2  incredible  2.397254
# 3   excellent  2.332343
# 4  phenomenal  2.298098

# %%
features.sort_values("coeff").head()
# Out:
#              word     coeff
# 127003      worst -3.293359
# 127002  poisoning -3.283280
# 127001   mediocre -3.275192
# 127000     lacked -3.156390
# 126999  tasteless -2.765787

# %% [markdown]
# ## Sentiment Analysis

# %%
print(review)
# Out:
# first time here cause people told they have good pizza. gave it a shot.they don't have good pizza. THEY HAVE GREAT PIZZA. this is east coast jersey new York boardwalk style  thin crust fold it in half and use your hands pizza.if you want to use a knife and fork to eat your pizza go back to chitown where you came from. I will be coming back.

# %%
# polarity ranges from -1 (most negative) to 1 (most positive)
review.sentiment.polarity
# Out:
# 0.22441077441077445

# %%
yelp_smaller['length'] = yelp_smaller.text.apply(len)
#Picking a subset of 250 reviews for sentiment analysis
yelp_smaller_subset = yelp_smaller.iloc[1:250, :]

# %%
# define a function that accepts text and returns the polarity
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
# create a new DataFrame column for sentiment
yelp_smaller['sentiment'] = yelp_smaller_subset.text.apply(detect_sentiment)

# %%
# boxplot of sentiment grouped by stars
yelp_smaller.boxplot(column='sentiment', by='stars')

# %%
#Adding the extra feature 'length' to the document term matrix

feature_cols = ['text','length']
X = yelp_smaller[feature_cols]
y = yelp_smaller.target
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# use CountVectorizer with text column only
yelp_pipeline = Pipeline([("countVect",CountVectorizer(stop_words="english")),
                     ("lr",LogisticRegression(C=0.1))])
strat_cv = StratifiedKFold(n_splits=2)
text_only_acc = np.mean(cross_val_score(yelp_pipeline,
                        X.text,
                        y,
                        scoring="accuracy",
                        cv=strat_cv,
                        n_jobs=-1,
                        verbose=1))
print("text only accuracy: ",np.round(text_only_acc,4))
# Out:
# ('text only accuracy: ', 0.94440000000000002)
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   38.4s finished

# %%
print("Original matrix: ",CountVectorizer(stop_words="english").fit_transform(X.text).shape)
# Out:
# ('Original matrix: ', (138578, 95828))
